# %%
import pandas as pd 
import numpy as np

# %%
file_path = "/Users/athuldas/Documents/DS/Internship/Projects/New project/Detailed India EV Market Data 2001 - 2024/csv's/"

# %%
file_name1 = "Fact_Category.csv"

# %%
file_name2 = "Fact_MakerSales.csv"

# %%
file_name3 = "CategoryMap.csv"

# %%
file_name4 = "Dim_MakerLocation.csv"

# %%
file_name5 = "Dim_State.csv"

# %%
file_name6 = "Maker_State_Presence.csv"

# %%
fact_category = pd.read_csv(file_path+file_name1)

# %%
fact_category.head()
# Out:
#          Date  Year                      RawCategory  Registrations  \
# 0  2001-01-01  2001  FOUR WHEELER (INVALID CARRIAGE)              0
# 1  2001-01-01  2001              HEAVY GOODS VEHICLE              1
# 2  2001-01-01  2001              HEAVY MOTOR VEHICLE              0
# 3  2001-01-01  2001          HEAVY PASSENGER VEHICLE              0
# 4  2001-01-01  2001              LIGHT GOODS VEHICLE              9
#
#   CategoryGroup
# 0            4W
# 1    Commercial
# 2    Commercial
# 3    Commercial
# 4            4W

# %%
fact_makersales = pd.read_csv(file_path+file_name2)

# %%
fact_makersales.head()
# Out:
#    MakerSalesID                        Maker RawCategory  Year  Sales  \
# 0             1  "VOLVO GROUP INDIA PVT LTD"          3W  2015      0
# 1             2  "VOLVO GROUP INDIA PVT LTD"          3W  2016      0
# 2             3  "VOLVO GROUP INDIA PVT LTD"          3W  2017     31
# 3             4  "VOLVO GROUP INDIA PVT LTD"          3W  2018     12
# 4             5  "VOLVO GROUP INDIA PVT LTD"          3W  2019      0
#
#   CategoryGroup
# 0            3W
# 1            3W
# 2            3W
# 3            3W
# 4            3W

# %%
categorymap = pd.read_csv(file_path+file_name3)

# %%
categorymap.head()
# Out:
#                        RawCategory CategoryGroup
# 0                               2W            2W
# 1                               3W            3W
# 2  FOUR WHEELER (INVALID CARRIAGE)            4W
# 3              HEAVY GOODS VEHICLE    Commercial
# 4              HEAVY MOTOR VEHICLE    Commercial

# %%
dim_makerlocation = pd.read_csv(file_path+file_name4)

# %%
dim_makerlocation.head()
# Out:
#                        Maker       Place       State
# 0       Ajanta Manufacturing       Morbi     Gujarat
# 1  Altigreen Propulsion Labs   Bengaluru   Karnataka
# 2            Ampere Vehicles  Coimbatore  Tamil Nadu
# 3              Ashok Leyland     Chennai  Tamil Nadu
# 4     Ashok Leyland (EV Bus)       Alwar   Rajasthan

# %%
dim_state = pd.read_csv(file_path+file_name5)

# %%
dim_state
# Out:
#     StateID           State  MakerCount  \
# 0         1  Andhra Pradesh           1
# 1         2           Delhi           4
# 2         3         Gujarat           5
# 3         4         Haryana           6
# 4         5       Karnataka           6
# 5         6  Madhya Pradesh           1
# 6         7     Maharashtra          15
# 7         8          Punjab           1
# 8         9       Rajasthan           4
# 9        10      Tamil Nadu          11
# 10       11       Telangana           3
# 11       12     Uttarakhand           1
# 12       13     West Bengal           3
#
#                                            MakersList  NoOfOperationalPCs
# 0                                    Kia Motors India                 327
# 1   Dilli Electric Auto Pvt Ltd, Euler Motors, Her...                1886
# 2   Ajanta Manufacturing, Atul Auto, Electrotherm ...                 476
# 3   Hero MotoCorp, JBM Auto, Maruti Suzuki India, ...                 377
# ...

# %%
maker_statepresence = pd.read_csv(file_path+file_name6)

# %%
maker_statepresence.head()
# Out:
#                        Maker       State
# 0       Ajanta Manufacturing     Gujarat
# 1  Altigreen Propulsion Labs   Karnataka
# 2            Ampere Vehicles  Tamil Nadu
# 3              Ashok Leyland  Tamil Nadu
# 4     Ashok Leyland (EV Bus)   Rajasthan

# %%
#####################################################
                  #data checks
#####################################################

# %%
################# Fact category

# %%
fact_category.shape
# Out:
# (4528, 5)

# %%
fact_category.columns
# Out:
# Index(['Date', 'Year', 'RawCategory', 'Registrations', 'CategoryGroup'], dtype='object')

# %%
fact_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4528 entries, 0 to 4527
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           4528 non-null   object
#  1   Year           4528 non-null   int64
#  2   RawCategory    4528 non-null   object
#  3   Registrations  4528 non-null   int64
#  4   CategoryGroup  4528 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 177.0+ KB

# %%
fact_category.duplicated().sum()
# Out:
# np.int64(0)

# %%
fact_category["RawCategory"].unique()
# Out:
# array(['FOUR WHEELER (INVALID CARRIAGE)', 'HEAVY GOODS VEHICLE',
#        'HEAVY MOTOR VEHICLE', 'HEAVY PASSENGER VEHICLE',
#        'LIGHT GOODS VEHICLE', 'LIGHT MOTOR VEHICLE',
#        'LIGHT PASSENGER VEHICLE', 'MEDIUM GOODS VEHICLE',
#        'MEDIUM PASSENGER VEHICLE', 'MEDIUM MOTOR VEHICLE',
#        'OTHER THAN MENTIONED ABOVE', 'THREE WHEELER(NT)',
#        'TWO WHEELER (INVALID CARRIAGE)', 'THREE WHEELER(T)',
#        'TWO WHEELER(NT)', 'TWO WHEELER(T)'], dtype=object)

# %%
fact_category["CategoryGroup"].unique()
# Out:
# array(['4W', 'Commercial', 'Other', '3W', '2W'], dtype=object)

# %%
# no of records : 4528
# columns       : 'Date', 'Year', 'RawCategory', 'Registrations', 'CategoryGroup'
# no duplicate records
# no missing values 
# !! date format issue date column is saved as datatype object (up for cleaning)
# 16 raw categories .
# 5 category groups

# %%
################# Fact makersales

# %%
fact_makersales.shape
# Out:
# (13860, 6)

# %%
fact_makersales.columns
# Out:
# Index(['MakerSalesID', 'Maker', 'RawCategory', 'Year', 'Sales',
#        'CategoryGroup'],
#       dtype='object')

# %%
fact_makersales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13860 entries, 0 to 13859
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MakerSalesID   13860 non-null  int64
#  1   Maker          13860 non-null  object
#  2   RawCategory    13860 non-null  object
#  3   Year           13860 non-null  int64
#  4   Sales          13860 non-null  int64
#  5   CategoryGroup  13860 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 649.8+ KB

# %%
fact_makersales.duplicated().sum()
# Out:
# np.int64(0)

# %%
fact_makersales["Year"].min()
# Out:
# 2015

# %%
fact_makersales["Year"].max()
# Out:
# 2024

# %%
# no of records   : 13860
# columns         : 'MakerSalesID', 'Maker', 'RawCategory', 'Year', 'Sales', 'CategoryGroup'
# no duplicate records
# no missing value
# no datatype issue
# data ranges from 2015 to 2024

# %%
################# Categorymap

# %%
categorymap.shape
# Out:
# (20, 2)

# %%
categorymap.columns
# Out:
# Index(['RawCategory', 'CategoryGroup'], dtype='object')

# %%
categorymap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RawCategory    20 non-null     object
#  1   CategoryGroup  20 non-null     object
# dtypes: object(2)
# memory usage: 452.0+ bytes

# %%
categorymap.duplicated().sum()
# Out:
# np.int64(0)

# %%
categorymap["CategoryGroup"].unique()
# Out:
# array(['2W', '3W', '4W', 'Commercial', 'Other'], dtype=object)

# %%
# no of records     : 20
# columns           : 'RawCategory', 'CategoryGroup'
# no duplicate records
# no missing values
# there are 20 RawCategories and 5 category groups

# %%
################# Dim makerlocation

# %%
dim_makerlocation.shape
# Out:
# (61, 3)

# %%
dim_makerlocation.columns
# Out:
# Index(['Maker', 'Place', 'State'], dtype='object')

# %%
dim_makerlocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Maker   61 non-null     object
#  1   Place   61 non-null     object
#  2   State   61 non-null     object
# dtypes: object(3)
# memory usage: 1.6+ KB

# %%
dim_makerlocation.duplicated(subset = "Maker").sum()
# Out:
# np.int64(0)

# %%
dim_makerlocation["State"].unique()
# Out:
# array(['Gujarat', 'Karnataka', 'Tamil Nadu', 'Rajasthan', 'Maharashtra',
#        'Delhi', 'Telangana', 'West Bengal', 'Haryana', 'Andhra Pradesh',
#        'Uttarakhand', 'Punjab', 'Madhya Pradesh'], dtype=object)

# %%
# no of records     : 61
# columns           : 'Maker', 'Place', 'State'
# no missing values
# no duplicate records
# there are 13 states and 61 makers

# %%
################# Dim state

# %%
dim_state.shape
# Out:
# (13, 5)

# %%
dim_state.columns
# Out:
# Index(['StateID', 'State', 'MakerCount', 'MakersList', 'NoOfOperationalPCs'], dtype='object')

# %%
dim_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   StateID             13 non-null     int64
#  1   State               13 non-null     object
#  2   MakerCount          13 non-null     int64
#  3   MakersList          13 non-null     object
#  4   NoOfOperationalPCs  13 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 652.0+ bytes

# %%
dim_state.duplicated().sum()
# Out:
# np.int64(0)

# %%
# no of records. : 13
# columns        : 'StateID', 'State', 'MakerCount', 'MakersList', 'NoOfOperationalPCs'
# no duplicated records
# no missing values
# there are 13 states

# %%
################# maker statepresence

# %%
maker_statepresence.shape
# Out:
# (61, 2)

# %%
maker_statepresence.columns
# Out:
# Index(['Maker', 'State'], dtype='object')

# %%
maker_statepresence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Maker   61 non-null     object
#  1   State   61 non-null     object
# dtypes: object(2)
# memory usage: 1.1+ KB

# %%
maker_statepresence.duplicated().sum()
# Out:
# np.int64(0)

# %%
# no of records   : 61
# columns         :'Maker', 'State'
# no missing values
# no duplicate records

# %%
#####################################################
                  # Detailed EDA
#####################################################

# %%
# Total sales all years

# %%
total_sales_all_years = fact_makersales["Sales"].sum()

# %%
total_sales_all_years
# Out:
# np.int64(4420903)

# %%
# top 10 makers by cumulative sales

# %%
top_10_makers_by_sales = fact_makersales.groupby(by=["Maker"]).agg({"Sales":"sum"}).sort_values(by="Sales",ascending=False).head(10)

# %%
top_10_makers_by_sales
# Out:
#                                     Sales
# Maker
# OLA ELECTRIC TECHNOLOGIES PVT LTD  588266
# TVS MOTOR COMPANY LTD              318445
# ATHER ENERGY PVT LTD               236387
# HERO ELECTRIC VEHICLES PVT. LTD    201785
# BAJAJ AUTO LTD                     198498
# OKINAWA AUTOTECH PVT LTD           196182
# YC ELECTRIC VEHICLE                152951
# AMPERE VEHICLES PRIVATE LIMITED    141805
# SAERA ELECTRIC AUTO PVT LTD         87481
# MAHINDRA & MAHINDRA LIMITED         84794

# %%
#
